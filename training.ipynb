# %%
import os
import shutil

# %%
# !pip install ultralytics roboflow

# %%
# !conda install -y gdown

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="u2o2ft5gbEMIAC0hqQgr")
project = rf.workspace("2-8hh1e").project("trying-lacmus-3-aug")
version = project.version(1)
dataset = version.download("yolov11")

# %%
os.remove("/kaggle/working/trying-lacmus-3-aug-1/data.yaml")

# %%
# !gdown 1et6UhEx2GP2x9-cgfKxnNqbxrFuLq1ec

# %%
# !yolo detect train model=yolo11l.pt data=/kaggle/working/dataset.yaml epochs=30 imgsz=960 batch=16 device=0,1 cos_lr=True seed=42

# %%
# !yolo detect train model=/kaggle/working/runs/detect/train3/weights/last.pt data=/kaggle/working/dataset.yaml epochs=20 imgsz=960 batch=16 device=0,1 cos_lr=True seed=42

# %%
# !gdown 1cjPjEvn0FqNdW5Wxyjx8ddGKzrtOOWZv

# %%
# !yolo detect train model=/kaggle/working/lacmus-960-best-till-now.pt data=/kaggle/working/dataset.yaml epochs=50 imgsz=960 batch=16 device=0,1 cos_lr=True seed=42
# Out:
# Ultralytics 8.3.31 🚀 Python-3.10.14 torch-2.4.0 CUDA:0 (Tesla T4, 15095MiB)
#                                                  CUDA:1 (Tesla T4, 15095MiB)
# ...
